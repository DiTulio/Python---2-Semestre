# %%
dicionário = {
    'time': ['A', 'B', 'C'],
    'vitorias': [10, 12, 8],
    'Estado': ['RJ', 'CE', 'SP']
}
print(dicionário)

import pandas as pd

dados = pd.DataFrame(dicionário)
dados

# %%
import pandas as pd

produto = dict(nome = "Notebook", preco=300)
print(produto("nome"))

Notebook

# %%
cliente = {}

cliente['nome'] = input("Nome: ")
cliente['idade'] = int(input("Idade: "))
cliente['cidade'] = input("Cidade: ")

print(f"Nome: {cliente['nome']}")
print(f"Idade: {cliente['idade']}")
print(f"Cidade: {cliente['cidade']}")

# %%
cliente = {"nome": "Ana", "Idade": 30}

cliente [idade] = 37
cliente.update('tel': 11999999999)
cliente.update({'endereço': 'av.paulista'})
del cliente["nome"]
tel = cliente.pop("tel")

print(cliente, tel)

# %%
produto = {"preco": 1200, "estoque": 3}

if produto['preco'] > 1000:
    categoria = 'Preco Alto'
else:
    categoria = 'Preco Baixo'

print(categoria)
# Out:
# Preco Alto

# %%
cliente = {"nome": "Ana", "idade": 31, "cidade": "SP"}
print(cliente.keys())
print(cliente.values())
print(cliente.items())

# %%
estoque = {
    "Maçã": 10,
    "Banana": 5,
    "Laranja": 8
}

for fruta, qtd in estoque.items():
    print(f"{fruta}: {qtd} unidades")
# Out:
# Maçã: 10 unidades
# Banana: 5 unidades
# Laranja: 8 unidades
