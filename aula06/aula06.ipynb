# %%
import pandas as pd
import numpy as np

vendas = pd.DataFrame({

    "pedido": [1001, 1002, 1003, 1004, 1005, 1006],
    "produto": ["Notebook", "Mouse", "Monitor",
    "Teclado", "Notebook", "Webcam"],
    "categoria": ["Informatica", "Acessorio",
    "Informatica", "Acessorio",
    "Informatica", "Acessorio"],
    "regiao": ["SP", "RJ", "SP", "MG", "RJ", "SP"],
    "preco": [4200.0, 89.9, 1350.0, 210.0, 3990.0, 149.9],
    "qtd": [2, 10, 3, 5, 1, 4],

})

df["total"] = df["preco"] * df["qtd"]

df[df["regiao"].isin(["SP", "RJ"])]

df[df["preco"].between(100, 1500)]

# %%
total = []
for i in range(len(df)):
  total.append(float(df['preco'] * df['qtd'][i]))
  print(total)

# %%
df['Total'] = df['preco'] * df['qtd']
df

# %%
#EX3
lista_acima = []
 
for i in range(len(def)):
  if df['Total'][i] > 1000:
    lista_acima.append(df['Total'][i])
print(lista_acima)

# %%
#EX4
 
mask = df['Total'] > 1000
valores_acima = df[mask]
print(valores acima)

# %%
#exerccio 1

df1 = df[df['regiao'] == 'RJ']

#exercicio 2
df1 = df[df['categoria'] == 'Informática']

#exercicio 
df1 = df[df['total'] > 1000 & df ['regiao'] == 'SP']

# %%
total = []

for i in range (len(df)):
    total.append(df['preco'] [i] * df['qtd'] [i])
df['total'] = total

df ['total'] = df['preco'] = df[total]

# %%
acima = []
for i in range(len(vendas)):
    if vendas ["total"] [i] > 1000:
        acima.append{vendas["total"] [i]}


mask = vendas ["total"] > 1000
acima = vendas[mask]

#ou, em uma linha só:

acima = vendas[vendas["total"] > 1000]
