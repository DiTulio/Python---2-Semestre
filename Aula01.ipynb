# %%
#Exemplo

lista_nomes = []
lista_idades = []
lista_sexo = []

for i in range (2):
    print(f"\n Dados da {i + 1}ª pessoa: ")
    nome = input("Digite o nome")
    lista_nomes.append(nome)
    idade = int(input("Digite a idade: "))
    lista_idades.append(idade)
    sexo = input("Digite M para masculino e F para feminino: ")
    lista_sexo.append(sexo)

print(lista_nomes)
print(lista_idades)
print(lista_sexo)

# %%
# #Exercício 1

# lista = []

# for i in range (2):
#     print(f"\n Dados da {i + 1}ª pessoa: ")
#     nome = input("Digite o nome")
#     lista.append(nome)
#     idade = int(input("Digite a idade: "))
#     lista.append(idade)
#     sexo = input("Digite M para masculino e F para feminino: ")
#     lista.append(sexo)

# print(lista)

##################################################################################
#Correção

lista_completa = []

for k in range(2):
    nome = input("Digite seu nome: ")
    idade = int(input("digite sua idade: "))
    sexo = input("Digite o sexo: (M/F): ")


    lista = [nome, idade, sexo]
    lista_completa.append(lista)

print(lista_completa)
# Out:
# [['h', 32, 'm'], ['t', 32, 'f']]

# %%
lista = ['A', 'B', 'C', 'D']
tupla = ['A', 'B', 'C', 'D']

dicionario = {
    'nome': ['A', 'B', 'C', 'D']
    'idade': ['18', '25', '32', '33']
}

print(lista)
print(tupla)
print(dicionario)

import panda as pd

dataframe = pd.DataFrame(dicionario)

# %%
#Versão 1
dados = [[],[],[],[],[]]
contador = 0

while contador <4:
    marca = input("Digite a marca do carro: ")
    modelo = input("Digite o modelo do carro: ")
    ano = int(input("Digite o ano do carro"))
    cor = input("Digite a cor do carro")
    ipva = input("Digite se o IPVA foi pago ou não: ")

    dados[0].append(marca)
    dados[1].append(modelo)
    dados[2].append(ano)
    dados[3].append(cor)
    dados[4].append(ipva)
    contador += 1

print(dados)

#############################################################################################################
#Versão 2

dados = []
contador = 0

while contador <4:
    marca = input("Digite a marca do carro: ")
    modelo = input("Digite o modelo do carro: ")
    ano = int(input("Digite o ano do carro"))
    cor = input("Digite a cor do carro")
    ipva = input("Digite se o IPVA foi pago ou não: ")

    lista = [marca, modelo, ano, cor, ipva]
    dados.append(lista)

print(dados)

# %%
dados = [[], [], [], [], []]
contador = 0

while contador <2:
    print(f"\n Dados da {contador + 1}ª pessoa: ")
    nome = input("Digite o nome: ")
    dados[0].append(nome)
    idade = int(input("Digite a idade: "))
    dados[1].append(idade)
    sexo = input("Digite o sexo da pessoa (M/F): ").lower()
    dados[2].append(sexo)
    contador += 1

print(f"\nLista consolidada por pessoa: ")
print(dados)

#########################################################################################################
#Correção
